# %% [markdown]
# # Sesión 2 - Repaso y ejercicios
#
# - Repasar numpy arrays
# - Repasar Pandas
# - Leer datos con Pandas
# - Funciones Universales

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('oec.csv')
pd.set_option('display.max_columns', None)
# pd.reset_option('max_columns') # si se deja este en vez del anterior, aparecerá el cuadro pero habtan 3 puntos para aplastar las demas columnas
data.head()
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0      HD 143761 b         0            1.0450        NaN   39.845800
# 1      HD 143761 c         0            0.0790        NaN  102.540000
# 2      KOI-1843.03         0            0.0014      0.054    0.176891
# 3      KOI-1843.01         0               NaN      0.114    4.194525
# 4      KOI-1843.02         0               NaN      0.071    6.356006
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0           0.2196         0.037          270.6           NaN
# 1           0.4123         0.050          190.0           NaN
# 2           0.0048           NaN            NaN           NaN
# 3           0.0390           NaN            NaN           NaN
# 4           0.0520           NaN            NaN           NaN
#
#    AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# 0               NaN             NaN           NaN     NaN              RV
# ...

# %%
data.describe()
# Out:
#           TypeFlag  PlanetaryMassJpt    RadiusJpt     PeriodDays  \
# count  3584.000000       1313.000000  2774.000000    3485.000000
# mean      0.097656          2.890944     0.371190     537.248317
# std       0.424554         10.204485     0.416871    7509.660676
# min       0.000000          0.000008     0.002300       0.090706
# 25%       0.000000          0.150000     0.141062       4.757940
# 50%       0.000000          0.940000     0.209600      13.071630
# 75%       0.000000          2.500000     0.321518      49.514000
# max       3.000000        263.000000     6.000000  320000.000000
#
#        SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# count      1406.000000   1108.000000     328.000000     43.000000
# mean          2.000170      0.166910     150.363823    144.200847
# std          19.352699      0.189760     117.859945    127.865952
# min           0.004420      0.000000    -233.000000   -174.640000
# ...

# %%
data.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'PlanetaryMassJpt', 'RadiusJpt',
#        'PeriodDays', 'SemiMajorAxisAU', 'Eccentricity', 'PeriastronDeg',
#        'LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg', 'SurfaceTempK',
#        'AgeGyr', 'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated',
#        'RightAscension', 'Declination', 'DistFromSunParsec',
#        'HostStarMassSlrMass', 'HostStarRadiusSlrRad', 'HostStarMetallicity',
#        'HostStarTempK', 'HostStarAgeGyr', 'ListsPlanetIsOn'],
#       dtype='object')

# %%
data.ListsPlanetIsOn.unique() #muestra nombre de columnas con nombrr planet
# Out:
# array(['Confirmed planets', 'Controversial',
#        'Confirmed planets, Planets in binary systems, S-type',
#        'Controversial, Planets in binary systems, S-type',
#        'Confirmed planets, Planets in binary systems, P-type',
#        'Controversial, Planets in binary systems, P-type', 'Solar System',
#        'Confirmed planets, Planets in open clusters',
#        'Confirmed planets, Orphan planets', 'Retracted planet candidate',
#        'Confirmed planets, Planets in binary systems, P-type, Planets in globular clusters',
#        'Planets in binary systems, S-type, Confirmed planets',
#        'Kepler Objects of Interest'], dtype=object)

# %%
data.loc[(data['ListsPlanetIsOn'] == 'Controversial') & (data['PlanetaryMassJpt'] > 7.5)]
# Out:
#             PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  \
# 141   Rho Coronae Borealis b         0           169.700        NaN
# 207              HD 131664 b         0            85.200        NaN
# 1048              HD 39392 b         0            13.200        NaN
# 1612             Kappa And b         0            50.000        NaN
# 1886          1SWASP J1407 b         0            14.000        NaN
# 2317    OGLE-2013-BLG-0102LB         0            13.000        NaN
# 2381                14 Her c         0             7.679        NaN
# 2631            BD+20 2457 b         0            21.420        NaN
# 2632            BD+20 2457 c         0            12.470        NaN
#
#       PeriodDays  SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 141      39.8449            0.240         0.057        303.000           NaN
# 207    1951.0000            3.170         0.638        149.700           NaN
# ...

# %%
len(controMass.columns)
# Out:
# 25

# %%
controMass.size
# Out:
# 225

# %%
controMass = data.loc[(data['ListsPlanetIsOn'] == 'Controversial') & (data['PlanetaryMassJpt'] > 7.5)] #se está creando un nuevo data frame

# %%
controMass.head()
# Out:
#             PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  \
# 141   Rho Coronae Borealis b         0             169.7        NaN
# 207              HD 131664 b         0              85.2        NaN
# 1048              HD 39392 b         0              13.2        NaN
# 1612             Kappa And b         0              50.0        NaN
# 1886          1SWASP J1407 b         0              14.0        NaN
#
#       PeriodDays  SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 141      39.8449             0.24         0.057          303.0           NaN
# 207    1951.0000             3.17         0.638          149.7           NaN
# 1048    394.3000             0.11         0.394            NaN           NaN
# 1612         NaN              NaN           NaN            NaN           NaN
# 1886  10044.0000              NaN         0.800            NaN           NaN
#
#       AscendingNodeDeg  InclinationDeg  SurfaceTempK  AgeGyr DiscoveryMethod  \
# ...

# %%
plt.hist(controMass.PlanetaryMassJpt)
# Out:
# (array([6., 0., 1., 0., 1., 0., 0., 0., 0., 1.]),
#  array([  7.679 ,  23.8811,  40.0832,  56.2853,  72.4874,  88.6895,
#         104.8916, 121.0937, 137.2958, 153.4979, 169.7   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.close()

# %% [markdown]
# ## Ejercicio 1 - 7 minutos
#
# - Exploremos el dataset. Cree un nuevo dataframe llamado 'method'
# 1. ¿Cuántos métodos únicos para descubrir exoplanetas contiene el dataset?
# 2. Cree un nuevo plot para visualizar la cantidad de descubrimientos por método usando un gráfico de pastel.

# %%
exPlanet= data.columns
exPlanet
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'PlanetaryMassJpt', 'RadiusJpt',
#        'PeriodDays', 'SemiMajorAxisAU', 'Eccentricity', 'PeriastronDeg',
#        'LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg', 'SurfaceTempK',
#        'AgeGyr', 'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated',
#        'RightAscension', 'Declination', 'DistFromSunParsec',
#        'HostStarMassSlrMass', 'HostStarRadiusSlrRad', 'HostStarMetallicity',
#        'HostStarTempK', 'HostStarAgeGyr', 'ListsPlanetIsOn'],
#       dtype='object')

# %%
data.DiscoveryMethod.unique()
# Out:
# array(['RV', 'transit', 'microlensing', nan, 'imaging', 'timing'],
#       dtype=object)

# %%
data.DiscoveryMethod.nunique()
# Out:
# 5

# %%
data.DiscoveryMethod.value_counts()
# Out:
# transit         2712
# RV               692
# imaging           52
# microlensing      40
# timing            25
# Name: DiscoveryMethod, dtype: int64

# %%
plt.pie(data.DiscoveryMethod.value_counts(),labels =['transit', 'RV', 'imaging', 'microlensing', 'timing'])
# Out:
# ([<matplotlib.patches.Wedge at 0x22a3b6b80a0>,
# ...
#  [Text(-0.8256606420534374, 0.7268318266035864, 'transit'),
#   Text(0.7454276384200149, -0.8089113893867238, 'RV'),
#   Text(1.0855283255598915, -0.17784334231884602, 'imaging'),
#   Text(1.0964552760120174, -0.0882373373658267, 'microlensing'),
#   Text(1.099726350987003, -0.024534729360873895, 'timing')])

# %%
plt.hist(data.DiscoveryMethod.value_counts())
# Out:
# (array([3., 0., 1., 0., 0., 0., 0., 0., 0., 1.]),
#  array([  25. ,  293.7,  562.4,  831.1, 1099.8, 1368.5, 1637.2, 1905.9,
#         2174.6, 2443.3, 2712. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Ejercicio 2 - 7 minutos
#
# - Exploremos el dataset. Cree un nuevo dataframe llamado 'discoveries'
# 1. ¿Cuántos planetas se descrubrieron en el 2016?
# 2. ¿Cuántos de esos planetas descubiertos en el 2016 fueron por el método de tránsito?

# %%
a = data.columns
a
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'PlanetaryMassJpt', 'RadiusJpt',
#        'PeriodDays', 'SemiMajorAxisAU', 'Eccentricity', 'PeriastronDeg',
#        'LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg', 'SurfaceTempK',
#        'AgeGyr', 'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated',
#        'RightAscension', 'Declination', 'DistFromSunParsec',
#        'HostStarMassSlrMass', 'HostStarRadiusSlrRad', 'HostStarMetallicity',
#        'HostStarTempK', 'HostStarAgeGyr', 'ListsPlanetIsOn'],
#       dtype='object')

# %%
discoveries = data.DiscoveryYear
discoveries
# Out:
# 0       2016.0
# 1       2016.0
# 2       2012.0
# 3          NaN
# 4          NaN
#          ...
# 3579    2014.0
# 3580    2014.0
# 3581    2003.0
# 3582    2005.0
# 3583    2016.0
# Name: DiscoveryYear, Length: 3584, dtype: float64

# %%
data.DiscoveryYear.unique()
# Out:
# array([2016., 2012.,   nan, 2010., 2014., 2009., 2005., 2013., 2001.,
#        1998., 2007., 2015., 2002., 2003., 2000., 2008., 1999., 2004.,
#        2017., 2011., 1997., 2006., 1781., 1846., 1930., 1992., 1996.,
#        1994., 1995.])

# %%
data.DiscoveryYear.nunique()
# Out:
# 28

# %%
data.DiscoveryYear.value_counts(2016)
# Out:
#   File "<ipython-input-45-76f4eef25616>", line 1
#     data.DiscoveryYear.value_counts(==2016)
#                                     ^
# SyntaxError: invalid syntax

# %%
twentySixteen = data.loc[(data.DiscoveryYear == 2016)]
twentySixteen
# Out:
#      PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0         HD 143761 b         0             1.045        NaN   39.845800
# 1         HD 143761 c         0             0.079        NaN  102.540000
# 9        Kepler-566 b         0               NaN      0.192   18.427946
# 10         WASP-124 b         0             0.600      1.240    3.372650
# 13      Kepler-1343 b         0               NaN      0.172    3.351832
# ...               ...       ...               ...        ...         ...
# 3570     Kepler-582 b         0               NaN      0.328   18.492357
# 3571        HD 222076         0             1.560        NaN  871.000000
# 3575    Kepler-1359 b         0               NaN      0.252   59.497095
# 3578     Kepler-658 b         0               NaN      0.145    1.287077
# 3583    Kepler-1473 b         0               NaN      0.106   14.427355
#
#       SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# ...

# %%
len(twentySixteen)
# Out:
# 1415

# %%
twentySixteen.ListsPlanetIsOn.unique()
# Out:
# array(['Confirmed planets', 'Controversial',
#        'Confirmed planets, Planets in open clusters',
#        'Confirmed planets, Planets in binary systems, S-type'],
#       dtype=object)

# %%
twentySixteenTransit = twentySixteen.loc[(data.DiscoveryYear == 2016) & (data.ListsPlanetIsOn == 'Confirmed planets') & (data.DiscoveryMethod == 'transit' )]

# %%
len(twentySixteenTransit)
# Out:
# 1347

# %%
twentySixteenTransit
# Out:
#      PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 9        Kepler-566 b         0               NaN      0.192   18.427946
# 10         WASP-124 b         0               0.6      1.240    3.372650
# 13      Kepler-1343 b         0               NaN      0.172    3.351832
# 14      Kepler-1011 b         0               NaN      0.256    5.753222
# 22      Kepler-1368 b         0               NaN      0.147    0.675649
# ...               ...       ...               ...        ...         ...
# 3569     Kepler-823 b         0               NaN      0.140    4.168091
# 3570     Kepler-582 b         0               NaN      0.328   18.492357
# 3575    Kepler-1359 b         0               NaN      0.252   59.497095
# 3578     Kepler-658 b         0               NaN      0.145    1.287077
# 3583    Kepler-1473 b         0               NaN      0.106   14.427355
#
#       SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# ...

# %% [markdown]
# ## Ejercicio 3 - 7 minutos
#
# - Exploremos el dataset. Cree un nuevo dataframe llamado 'masses'
# 1. ¿Cuántos planetas en el 2016 tienen una masa mayor a 1 MJpt?
# 2. ¿Cuánto es el total de las masas del punto 1?
# 3. Cree un histograma para visualizar la distribución general de las masas de los planetas

# %%
b = data.columns
b
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'PlanetaryMassJpt', 'RadiusJpt',
#        'PeriodDays', 'SemiMajorAxisAU', 'Eccentricity', 'PeriastronDeg',
#        'LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg', 'SurfaceTempK',
#        'AgeGyr', 'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated',
#        'RightAscension', 'Declination', 'DistFromSunParsec',
#        'HostStarMassSlrMass', 'HostStarRadiusSlrRad', 'HostStarMetallicity',
#        'HostStarTempK', 'HostStarAgeGyr', 'ListsPlanetIsOn'],
#       dtype='object')

# %%
masses = data.HostStarMassSlrMass
masses
# Out:
# 0       0.889
# 1       0.889
# 2       0.460
# 3       0.460
# 4       0.460
#         ...
# 3579    1.700
# 3580    1.700
# 3581    1.000
# 3582    1.000
# 3583    1.090
# Name: HostStarMassSlrMass, Length: 3584, dtype: float64

# %%
masses2 = masses.loc[(data.ListsPlanetIsOn == 'Confirmed planets') & (data['HostStarMassSlrMass'] > 1) & (data.DiscoveryYear == 2016) ]
masses2
# Out:
# 10      1.07
# 22      1.07
# 25      1.10
# 26      1.10
# 47      1.34
#         ...
# 3552    1.04
# 3555    1.01
# 3567    1.14
# 3571    1.07
# 3583    1.09
# Name: HostStarMassSlrMass, Length: 581, dtype: float64

# %%
masses2.size
# Out:
# 581

# %%
masses2.head()
# Out:
# 10    1.07
# 22    1.07
# 25    1.10
# 26    1.10
# 47    1.34
# Name: HostStarMassSlrMass, dtype: float64

# %%
plt.hist(data.HostStarMassSlrMass.value_counts(1))
# Out:
# (array([471.,  21.,   7.,  10.,   8.,   9.,   6.,   5.,   0.,   1.]),
#  array([0.00029274, 0.00269321, 0.00509368, 0.00749415, 0.00989461,
#         0.01229508, 0.01469555, 0.01709602, 0.01949649, 0.02189696,
#         0.02429742]),
#  <BarContainer object of 10 artists>)
